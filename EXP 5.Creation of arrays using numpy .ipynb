# %%
#Exp no.:5

# %%
#Aim: Creation of arrays using numpy

# %%
# Name:Shalimar R Kathade
# Roll no:74
# Sec: C
# Subject:ET1

# %%
import numpy as np

# %%
#creating 1D array 
a1=np.array([11,22,33,44])

# %%
a1
# Out:
# array([11, 22, 33, 44])

# %%
#creating 2D array
a2=np.array([[15, 25, 35, 45, 55],[10, 20, 30, 40, 50]])

# %%
a2
# Out:
# array([[15, 25, 35, 45, 55],
#        [10, 20, 30, 40, 50]])

# %%
#creating 3d array
a3=np.matrix('10,15;20,25;30,35')

# %%
a3
# Out:
# matrix([[10, 15],
#         [20, 25],
#         [30, 35]])

# %%
#create array of 30 random integers between 15 and 26
arr=np.random.randint(10,26,size=30)
print(arr)
# Out:
# [23 15 16 15 12 17 16 18 23 18 17 12 11 18 19 24 22 11 24 18 23 14 10 22
#  20 16 22 14 25 19]
