# %%
#Exp no.:02

# %%
#Aim:Central tendency of measures mean median mode

# %%
# Name:Shalimar R Kathade
# Roll no:74
# Sec: C
# Subject:PE
# Date:01/08/2025

# %%
age=[21,23,65,78,57,56,45,34,43,14,63,65,20,25,26]

# %%
age
# Out:
# [21, 23, 65, 78, 57, 56, 45, 34, 43, 14, 63, 65, 20, 25, 26]

# %%
print(age)
# Out:
# [21, 23, 65, 78, 57, 56, 45, 34, 43, 14, 63, 65, 20, 25, 26]

# %%
import statistics

# %%
a=statistics.mean(age)

# %%
a
# Out:
# 42.333333333333336

# %%
b=statistics.mean(age)

# %%
b
# Out:
# 42.333333333333336

# %%
c=statistics.mode(age)

# %%
c
# Out:
# 65

# %%
import numpy as np

# %%
x=np.array([1,2,3,4,5,6,7,2,6,2,1,4,2,2,6])

# %%
x
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 2, 6, 2, 1, 4, 2, 2, 6])

# %%
print(np.mean(x))
# Out:
# 3.533333333333333

# %%
print(np.median(x))
# Out:
# 3.0

# %% [raw]
# from scipy import stats

# %%
print(stats.mode(x))
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(5))

# %%
print(np.std(x))
# Out:
# 1.9618585292749546

# %%
print(np.var(x))
# Out:
# 3.8488888888888884
